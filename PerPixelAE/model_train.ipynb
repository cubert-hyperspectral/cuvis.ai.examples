# %%
import os
import gc
import sys
import time
import numpy as np
import matplotlib.pyplot as plt
import cuvis
import glob
from collections import defaultdict
import cv2
from torch.utils.data import Dataset
from pycocotools import mask as maskUtils
from enum import Enum
from sklearn.manifold import TSNE
from tqdm.notebook import tqdm
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import minmax_scale
from sklearn.utils import shuffle
from sklearn.metrics import accuracy_score, classification_report
from sklearnex import patch_sklearn
from skorch import NeuralNetClassifier, NeuralNetRegressor
from skorch.callbacks import LRScheduler, EarlyStopping, Checkpoint, ProgressBar
import torch
import skorch
import pickle
import numpy as np
from scipy.stats import chi2
from sklearn import preprocessing 
from torch import nn
import torch.nn.functional as F
from pretty_confusion_matrix import pp_matrix_from_data
import concurrent.futures
# Set us to use the GPU when appropriate
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Using {device} for pytorch models...')
# %matplotlib inline
# Out:
# Using cuda for pytorch models...

# %% [markdown]
# ### Transform .cu3s Dataset to .npy
#
# This will save approximately 35 seconds per load operation (and only needs to be run once)

# %%
import concurrent.futures
import time
from tqdm.notebook import tqdm

def process_item(cube):
    # Load the cube to the numpy array
    cube_data = cuvis.SessionFile(cube).get_measurement(0).cube.to_numpy()
    # Save the measurement as numpy format
    np.save(cube.replace('.cu3s', '.npy'), cube_data)
    # Remove the data
    os.remove(cube)

def parallel_transform_with_progress(data, transform_fn, num_workers=4):
    """
    Parallelizes a transformation function with progress tracking using tqdm.

    Parameters:
        data (iterable): The input data to transform.
        transform_fn (callable): A function to apply to each element.
        num_workers (int): Number of parallel processes.

    Returns:
        list: Transformed data.
    """
    results = []
    with concurrent.futures.ProcessPoolExecutor(max_workers=num_workers) as executor:
        # Submit jobs and wrap with tqdm for progress tracking
        futures = {executor.submit(transform_fn, item): item for item in data}
        for future in tqdm(concurrent.futures.as_completed(futures), total=len(data), desc="Processing"):
            results.append(future.result())  # Collect result when done
    return results


data = list(glob.glob('/home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/*.cu3s'))
transformed_data = parallel_transform_with_progress(data, process_item, num_workers=4)
print(transformed_data)
# Out:
# Processing: 0it [00:00, ?it/s]
# []

# %%
class CubeDataset(Dataset):
    """
    A PyTorch Dataset for a directory of hyperspectral cubes.
    
    Each hyperspectral image is stored as a .npy file with shape
        (height, width, bands).
    
    When __getitem__ is called, the corresponding hyperspectral cube is loaded 
    from disk (lazy loading) and returned (optionally with a transform).
    """
    def __init__(self, data_dir, subset: int =4, eval=False, RGB=False, SWIR=False, crop=1):
        """
        Parameters:
            data_dir (str): Path to the directory containing hyperspectral cube files (.npy).
            subset (int): Amount to downsample the shuffled hyperspectral data
        """
        self.data_dir = data_dir
        # Ablation - use RGB
        self.RGB = RGB
        # Ablation - use SWIR
        self.SWIR = SWIR
        # Crop - exclude edges
        self.crop = crop
        # List all .npy files in the directory, sorted for reproducibility.
        self.eval=eval
        if not eval:
            self.filenames = sorted([f for f in glob.glob(data_dir) if (f.endswith('.npy') and ('_ok_ok' in f) and ('pred' not in f))])
            print(f'Training from {len(self.filenames)} samples')
        else:
            self.filenames = sorted([f for f in glob.glob(data_dir) if ((f.endswith('.npy') and 'prediction' not in f and (('_ok_ok' in f) or ('_nok_ok' in f) or ('_ok_nok' in f) or ('_nok_nok' in f))))])
            print(f'Evaluating {len(self.filenames)} samples')
        if not self.filenames:
            raise ValueError("No .npy files found in the provided data directory.")
        # Apply the subset
        self.subset = subset
        # Calculate dark ref
        self.calculate_dark_ref(data_dir)
        # Calculate white ref
        self.calculate_white_ref(data_dir)

    def calculate_dark_ref(self, data_dir):
        filenames = sorted([f for f in glob.glob(data_dir) if (f.endswith('.npy') and '_ref_dark' in f)])
        print(f'Found {len(filenames)} dark reference files')
        cubes = np.array([np.load(cube)[self.crop:-self.crop:self.subset, self.crop:-self.crop:self.subset, :] for cube in filenames])
        self.dark_ref = np.mean(cubes, axis=0)
        print(f'Calculated dark reference with a size of {self.dark_ref.shape}')

    def calculate_white_ref(self, data_dir):
        filenames = sorted([f for f in glob.glob(data_dir) if (f.endswith('.npy') and '_ref_white' in f)])
        print(f'Found {len(filenames)} white reference files')
        cubes = np.array([np.load(cube)[self.crop:-self.crop:self.subset, self.crop:-self.crop:self.subset, :] for cube in filenames])
        self.white_ref = np.mean(cubes, axis=0)
        print(f'Calculated white reference with a size of {self.white_ref.shape}')

    def reflectance(self, cube):
        return np.clip(
            np.nan_to_num((cube - self.dark_ref) / (self.white_ref/0.40 - self.dark_ref)),
            0, 1.00).astype(np.float32)

    def __len__(self):
        return len(self.filenames)

    def __getitem__(self, idx):
        if idx < 0 or idx >= len(self):
            raise IndexError("Index out of range")
        
        fname = self.filenames[idx]
        file_path = os.path.join(self.data_dir, fname)
        
        # Load the entire hyperspectral cube lazily.
        cube = np.load(file_path)[self.crop:-self.crop:self.subset, self.crop:-self.crop:self.subset, :]
        
        # Reflectance calibrate_cube
        cube = self.reflectance(cube)
        height, width, n_bands = cube.shape
        
        # Flatten the cube: each row is a pixel's spectrum.
        # The resulting shape will be (height * width, bands)
        data = cube.reshape(-1, n_bands).astype(np.float32)
        if self.RGB:
            data = data[:,:3]
        if self.SWIR:
            data = data[:,3:]
        if not self.eval:
            # Subset the data
            np.random.shuffle(data)
            return data, data # We need both for x and y values
        else:
            return data, fname, (height, width, n_bands)

# %% [markdown]
# ## Define Skorch Autoencoder Models

# %%
# Define the PyTorch model
class Autoencoder(nn.Module):
    def __init__(self, encoding_dim: int, wave: int):
        super(Autoencoder, self).__init__()
        # Encoder layers
        self.encoder = nn.Sequential(
            nn.Linear(wave, 150),
            nn.ReLU(),
            nn.Linear(150, 100),
            nn.ReLU(),
            nn.Linear(100, 75),
            nn.ReLU(),
            nn.Linear(75, 50),
            nn.ReLU(),
            nn.Linear(50, encoding_dim)
        )
        # Decoder layers
        self.decoder = nn.Sequential(
            nn.Linear(encoding_dim, 50),
            nn.ReLU(),
            nn.Linear(50, 75),
            nn.ReLU(),
            nn.Linear(75, 100),
            nn.ReLU(),
            nn.Linear(100, wave),
            nn.Sigmoid()
        )

    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

class AutoencoderSmall(nn.Module):
    def __init__(self, encoding_dim: int, wave: int):
        super(AutoencoderSmall, self).__init__()
        # Encoder layers
        self.encoder = nn.Sequential(
            nn.Linear(wave, 5),
            nn.ReLU(),
            nn.Linear(5, 3),
            nn.ReLU(),
            nn.Linear(3, encoding_dim)
        )
        # Decoder layers
        self.decoder = nn.Sequential(
            nn.Linear(encoding_dim, 3),
            nn.ReLU(),
            nn.Linear(3, 5),
            nn.ReLU(),
            nn.Linear(5, wave),
            nn.Sigmoid()
        )

    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded


# Create early stopping patience
early_stopping = EarlyStopping(monitor='valid_loss', patience = 10, threshold = 0.01, threshold_mode='rel', lower_is_better=True)


class CosSpectralAngleLoss(nn.Module):
    def __init__(self):
        super(CosSpectralAngleLoss, self).__init__()
    def forward(self, y, y_reconstructed):
        # Normalize y and y_reconstructed along the feature dimension
        # This should normalize along the length of the spectral vector
        epsilon = 1e-8
        normalize_r = torch.sqrt(torch.sum(y_reconstructed**2, dim=1)) + epsilon
        # This should also normalize along the length of the spectral vector
        normalize_t = torch.sqrt(torch.sum(y**2, dim=1))
        # Compute cosine similarity between the normalized vectors
        numerator = torch.sum((y * y_reconstructed), dim=1)
        denominator = normalize_r * normalize_t
        cosine_similarity = numerator / denominator
        # Compute the spectral angle in radians
        spectral_angle = torch.acos(cosine_similarity)
        spectral_angle = torch.nan_to_num(cosine_similarity, 1)
        # # When a function perfectly matches, the value is 0
        # # Torch acos is define over [-1,1]
        # # To make this an appropriate loss value, we need to invert the spread and then add 1
        spectral_angle = (-1 * spectral_angle) + 1
        # Average the spectral angle to get the final loss
        loss = torch.mean(spectral_angle)
        return loss

class HybridLoss(nn.Module):
    def __init__(self):
        super(HybridLoss, self).__init__()
        self.MSELoss = nn.MSELoss()
        # Controls the weighting of the importance between MSE and SAM
        self.alpha = 0.1

    def forward(self, y, y_reconstructed):
        return self.forward_mse(y,y_reconstructed) + self.alpha * self.forward_sam(y, y_reconstructed)

    def forward_sam(self, y, y_reconstructed):
        # Normalize y and y_reconstructed along the feature dimension
        # This should normalize along the length of the spectral vector
        epsilon = 1e-8
        normalize_r = torch.sqrt(torch.sum(y_reconstructed**2, dim=1)) + epsilon
        # This should also normalize along the length of the spectral vector
        normalize_t = torch.sqrt(torch.sum(y**2, dim=1))
        # Compute cosine similarity between the normalized vectors
        # This is computer
        numerator = torch.sum((y * y_reconstructed), dim=1)
        denominator = normalize_r * normalize_t
        cosine_similarity = numerator / denominator
        # Compute the spectral angle in radians
        spectral_angle = torch.acos(cosine_similarity)
        spectral_angle = torch.nan_to_num(cosine_similarity, 1)
        # When a function perfectly matches, the value is 0
        # Torch acos is define over [-1,1]
        # To make this an appropriate loss value, we need to invert the spread and then add 1
        spectral_angle = (-1 * spectral_angle) + 1
        # Average the spectral angle to get the final loss
        loss = torch.mean(spectral_angle)
        return loss
    
    def forward_mse(self, y, y_reconstructed):
        return self.MSELoss.forward(y, y_reconstructed)

# %% [markdown]
# ### Utility Functions

# %%
# Initialize the model and the Skorch wrapper
def create_skorch_model(encoding_dim: int, wave: int, large=True, loss='MSE', use_tensorboard=True) -> NeuralNetRegressor:
    if large:
        autoencoder = Autoencoder(encoding_dim, wave)
    else:
        autoencoder = AutoencoderSmall(encoding_dim, wave)
    # Choose loss function
    loss_lookup = {
        'MSE': nn.MSELoss,
        'SAM': CosSpectralAngleLoss,
        'Hybrid': HybridLoss
    }
    try:
        loss_fnc = loss_lookup[loss]
    except KeyError as e:
        print('Invalid loss function!')
        sys.exit(1)
    print(f'Using {loss} as loss!')
    # Add a monitor to save the best performance
    monitor = lambda net: all(net.history[-1, ('train_loss_best', 'valid_loss_best')])
    checkpoint = Checkpoint(monitor=monitor, f_params="params_{last_epoch[epoch]}.pt")
    # Create initial callbacks
    callbacks = [ProgressBar(),early_stopping, checkpoint]
    # Enable us to view model performance through the TensorBoard GUI
    if use_tensorboard:
        from torch.utils.tensorboard import SummaryWriter
        from skorch.callbacks import TensorBoard
        writer = SummaryWriter()
        callbacks.append(TensorBoard(writer))
    skorch_model = NeuralNetRegressor(
        autoencoder,
        max_epochs=100,    # adjust as needed
        lr=0.01,
        optimizer = torch.optim.Adam,
        criterion = loss_fnc, # Chose loss function class here
        callbacks = callbacks,
        batch_size = 7, # This will need to vary based on the computer utilized
        iterator_train__shuffle=True,
        device='cuda' if torch.cuda.is_available() else 'cpu'
    )
    return skorch_model

def batch_predict(model, dataloader):
    pass


# Predict some sample images here
def visualize_model_performance(autoencoder: NeuralNetRegressor, cube_data: dict, threshold: float=0.15, title='', factor=1):
    # Make a single figure
    samples = len(cube_data.keys())
    i = 0
    fig, ax = plt.subplots(samples, 2, figsize=(15, 5*samples))
    for name, cube in tqdm(cube_data.items()):
        # Grab the correct pixels
        input_pixels = cube['data'][::10,::10,:].reshape(-1, cube['data'][::10,::10,:].shape[-1]).astype(np.float32) / factor
        start_time = time.time_ns()
        predicted_pixels = autoencoder.predict(input_pixels)
        stop_time = time.time_ns()
        print(f'Predicted reconstruction error in {(stop_time-start_time)/10**9} seconds')
        predicted_cube = predicted_pixels.reshape(cube['data'][::10,::10,:].shape)
        # Calculate L2 error and visualize
        # Plot RGB, ground truth, and predicted labels side by side
        error_img = np.linalg.norm(predicted_cube-(cube['data'][::10,::10,:] / factor), axis=2)
        im = ax[i, 0].imshow(error_img)
        ax[i, 0].set_title(f'Reconstruction Loss for Scene: {name}')
        fig.colorbar(im, label='Reconstruction Error')
        image = cv2.cvtColor((cube['data']/factor)[:,:,:3].astype(np.float32), cv2.COLOR_BGR2RGB)
        ax[i, 1].imshow(image)
        ax[i, 1].set_title('RGB Representation')
        # Increment the row
        i+= 1
    plt.suptitle(f'Autoencoder Performance for {title}', y=1.01)
    plt.tight_layout()
    plt.show()

def save_model(model: NeuralNetRegressor, file_name='.'):
    '''
    Save model to file
    '''
    with open(file_name, 'wb') as f:
        pickle.dump(model, f)

def load_model(model: NeuralNetRegressor, file_name='.') -> NeuralNetRegressor:
    '''
    Load autoencoder and return object
    '''
    with open(file_name, 'rb') as f:
        model  = pickle.load(f)
        return model

# %%
def create_inference_png(img, pred, image_name, max_pred, plot_thresholds=[0.001, 0.002,0.005, 0.01,0.02,0.025, 0.05]):
    nrows = 2 + len(plot_thresholds)
    fig_height = 6 + len(plot_thresholds)
    fig, ax = plt.subplots(nrows, 2, tight_layout=True, dpi=300, figsize=(10, fig_height))
    a_map = pred
    a_map = a_map + abs(a_map.min())
    if a_map.max() > 0:
        a_map = a_map / (max_pred + abs(a_map.min()))

    if img.shape[2] > 3:
        ir = img[:,:,3:]
        rgb = img[:,:,[2,1,0]]

    ax[0][0].imshow((rgb * 255).astype(np.uint8), vmax=255, vmin=0)
    ax[0][1].imshow((ir* 255).astype(np.uint8), vmax=255, vmin=0)
    ax[0][0].set_title('RGB')
    ax[0][1].set_title('IR')
    ax[1][0].imshow((a_map * 255).astype(np.uint8), vmax=255, vmin=0)
    ax[1][0].set_title('anomaly_map ')
    overlay = ir.copy()
    mask = a_map > np.array(plot_thresholds).min()
    overlay[mask,1] = a_map[mask]

    ax[1][1].imshow((overlay * 255).astype(np.uint8), vmax=255, vmin=0)
    ax[1][1].set_title('IR_overlay')
    for i, threshold in enumerate(plot_thresholds):
        a_map_threshold = a_map.copy()
        a_map_threshold[a_map_threshold < threshold] = 0
        a_map_threshold[a_map_threshold >= threshold] = 1
        ax[2 + i][0].set_title(f'anomaly_map_threshold: {threshold}')
        overlay = ir.copy()
        overlay[a_map_threshold == 1] = [1, 0, 0]
        ax[2 + i][0].imshow((a_map_threshold * 255).astype(np.uint8), vmax=255, vmin=0)
        ax[2 + i][1].imshow((overlay * 255).astype(np.uint8), vmax=255, vmin=0)


        ax[2 + i][1].set_title('IR_overlay with threshold')
    fig.suptitle(image_name)
    return fig, ax

# %% [markdown]
# ### Create Dataloader

# %%
hsi_data = CubeDataset('/home/nathaniel/Downloads/yogurt_data_deploy/train_eval/*/*', subset=10, eval=False, RGB=False, SWIR=True, crop=300)
# Out:
# Training from 1363 samples
# Found 10 dark reference files
# Calculated dark reference with a size of (180, 430, 6)
# Found 39 white reference files
# Calculated white reference with a size of (180, 430, 6)

# %% [markdown]
# ### Train Model with Full Dataset

# %%
autoencoder_large_hybrid = create_skorch_model(1, 3, large=True, loss='Hybrid')
autoencoder_large_hybrid.fit(hsi_data, None)
# Out:
# Using Hybrid as loss!
# 2025-02-18 09:14:44.219146: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1739888084.288242    6620 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1739888084.308028    6620 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-18 09:14:44.446804: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#   0%|          | 0/195 [00:00<?, ?it/s]
#   epoch    train_loss    valid_loss    cp        dur
# -------  ------------  ------------  ----  ---------
#       1        0.0021        0.0004     +  1152.2229
#   0%|          | 0/195 [00:00<?, ?it/s]
#       2        0.0003        0.0004     +  1216.9458
#   0%|          | 0/195 [00:00<?, ?it/s]
#       3        0.0003        0.0004        298.9511
#   0%|          | 0/195 [00:00<?, ?it/s]
#       4        0.0003        0.0004        300.4879
#   0%|          | 0/195 [00:00<?, ?it/s]
#       5        0.0003        0.0005        293.6741
#   0%|          | 0/195 [00:00<?, ?it/s]
#       6        0.0003        0.0004        286.2698
#   0%|          | 0/195 [00:00<?, ?it/s]
#       7        0.0003        0.0005        284.2977
#   0%|          | 0/195 [00:00<?, ?it/s]
#       8        0.0003        0.0005        282.7682
#   0%|          | 0/195 [00:00<?, ?it/s]
#       9        0.0003        0.0004        282.4134
#   0%|          | 0/195 [00:00<?, ?it/s]
#      10        0.0003        0.0004        281.0670
#   0%|          | 0/195 [00:00<?, ?it/s]
#      11        0.0003        0.0004        280.2650
#   0%|          | 0/195 [00:00<?, ?it/s]
# Stopping since valid_loss has not improved in the last 10 epochs.
# <class 'skorch.regressor.NeuralNetRegressor'>[initialized](
#   module_=Autoencoder(
#     (encoder): Sequential(
#       (0): Linear(in_features=3, out_features=150, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=150, out_features=100, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=100, out_features=75, bias=True)
#       (5): ReLU()
#       (6): Linear(in_features=75, out_features=50, bias=True)
#       (7): ReLU()
#       (8): Linear(in_features=50, out_features=1, bias=True)
#     )
#     (decoder): Sequential(
#       (0): Linear(in_features=1, out_features=50, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=50, out_features=75, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=75, out_features=100, bias=True)
#       (5): ReLU()
#       (6): Linear(in_features=100, out_features=3, bias=True)
#       (7): Sigmoid()
#     )
#   ),
# )

# %%
import dill as pickle
save_model(autoencoder_large_hybrid, './yogurt_models/autoencoder_large_hybrid_production_02_13_25_swir.pkl')
autoencoder_large_hybrid.save_params(f_params='autoencoder_large_hybrid_production_02_13_25_swir_params.pkl')

# %%
# import dill as pickle
autoencoder_large_hybrid = create_skorch_model(3, 6, large=True, loss='Hybrid')
autoencoder_large_hybrid.initialize()
autoencoder_large_hybrid.load_params(f_params='autoencoder_large_hybrid_production_02_09_25_params.pkl')
# Out:
# Using Hybrid as loss!

# %%
# Create testing dataset
# hsi_data = CubeDataset('/home/nathaniel/Downloads/yogurt_data_deploy/playtime/*/*', subset=10, eval=True)
hsi_data = CubeDataset('/home/nathaniel/Downloads/yogurt_data_deploy/playtime/*/*', subset=10, eval=True)
# Out:
# Evaluating 138 samples
# Found 35 dark reference files
# Calculated dark reference with a size of (240, 490, 6)
# Found 70 white reference files
# Calculated white reference with a size of (240, 490, 6)

# %% [markdown]
# ### Feed Dataset through Model

# %%
# test = []
# rgb = []
for sample in tqdm(hsi_data):
    pred = autoencoder_large_hybrid.predict(sample[0])
    pred = pred.reshape(sample[2])
    error_img = np.linalg.norm(pred-sample[0].reshape(sample[2]), axis=2)
    # test.append(error_img)
    # Save the data
    save_name = sample[1][:-4] + '_prediction_02_18_swir.npy'
    # rgb.append(cv2.imread(sample[1][:-4] + '.jpg'))
    np.save(save_name, error_img)
# Out:
#   0%|          | 0/138 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[11], line 4
#       1 # test = []
#       2 # rgb = []
#       3 for sample in tqdm(hsi_data):
# ----> 4     pred = autoencoder_large_hybrid.predict(sample[0])
#       5     pred = pred.reshape(sample[2])
#       6     error_img = np.linalg.norm(pred-sample[0].reshape(sample[2]), axis=2)
#
# File ~/.local/lib/python3.10/site-packages/skorch/net.py:1632, in NeuralNet.predict(self, X)
#    1602 def predict(self, X):
#    1603     """Where applicable, return class labels for samples in X.
#    1604
#    1605     If the module's forward method returns multiple outputs as a
#    (...)
#    1630
#    1631     """
# -> 1632     return self.predict_proba(X)
#
# File ~/.local/lib/python3.10/site-packages/skorch/net.py:1595, in NeuralNet.predict_proba(self, X)
#    1593 nonlin = self._get_predict_nonlinearity()
#    1594 y_probas = []
# -> 1595 for yp in self.forward_iter(X, training=False):
#    1596     yp = yp[0] if isinstance(yp, tuple) else yp
#    1597     yp = nonlin(yp)
#
# File ~/.local/lib/python3.10/site-packages/skorch/net.py:1441, in NeuralNet.forward_iter(self, X, training, device)
#    1439 iterator = self.get_iterator(dataset, training=training)
#    1440 for batch in iterator:
# -> 1441     yp = self.evaluation_step(batch, training=training)
#    1442     yield to_device(yp, device=device)
#
# File ~/.local/lib/python3.10/site-packages/skorch/net.py:1134, in NeuralNet.evaluation_step(self, batch, training)
#    1132 with torch.set_grad_enabled(training):
#    1133     self._set_training(training)
# -> 1134     return self.infer(Xi)
#
# File ~/.local/lib/python3.10/site-packages/skorch/net.py:1521, in NeuralNet.infer(self, x, **fit_params)
#    1519     x_dict = self._merge_x_and_fit_params(x, fit_params)
#    1520     return self.module_(**x_dict)
# -> 1521 return self.module_(x, **fit_params)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# Cell In[4], line 30, in Autoencoder.forward(self, x)
#      29 def forward(self, x):
# ---> 30     encoded = self.encoder(x)
#      31     decoded = self.decoder(encoded)
#      32     return decoded
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/linear.py:116, in Linear.forward(self, input)
#     115 def forward(self, input: Tensor) -> Tensor:
# --> 116     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (7x6 and 3x150)

# %% [markdown]
# ### Run the RGB Ablation Results

# %%
autoencoder_large_hybrid = create_skorch_model(3, 3, large=True, loss='Hybrid')
autoencoder_large_hybrid.initialize()
autoencoder_large_hybrid.load_params(f_params='autoencoder_large_hybrid_production_02_11_25__rgb_params.pkl')
# Out:
# Using Hybrid as loss!
# 2025-02-12 18:16:58.276951: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1739402218.320081    9398 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1739402218.332726    9398 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-12 18:16:58.438403: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
hsi_data = CubeDataset('/home/nathaniel/Downloads/yogurt_data_deploy/train_eval/*/*', subset=10, eval=True)
# Out:
# Evaluating 1571 samples
# Found 10 dark reference files
# Calculated dark reference with a size of (240, 490, 6)
# Found 39 white reference files
# Calculated white reference with a size of (240, 490, 6)

# %%
# test = []
# rgb = []
for sample in tqdm(hsi_data):
    pred = autoencoder_large_hybrid.predict(sample[0][:,3:])
    pred = pred.reshape(*sample[2][0:2],3)
    error_img = np.linalg.norm(pred-sample[0][:,3:].reshape((*sample[2][0:2],3)), axis=2)
    # test.append(error_img)
    # Save the data
    save_name = sample[1][:-4] + '_prediction_02_18_swir.npy'
    # rgb.append(cv2.imread(sample[1][:-4] + '.jpg'))
    np.save(save_name, error_img)
# Out:
#   0%|          | 0/1571 [00:00<?, ?it/s]

# %%
dark_ref = np.mean(np.array([np.load(z)[::10,::10,:] for z in glob.glob('/home/nathaniel/Downloads/yogurt_data_deploy/*/*/*ref_dark*.npy')]), axis=0)
white_ref = np.mean(np.array([np.load(z)[::10,::10,:] for z in glob.glob('/home/nathaniel/Downloads/yogurt_data_deploy/*/*/*ref_white*.npy')]), axis=0)

# %%
def reflectance(cube, dark_ref, white_ref):
    return np.clip(
        np.nan_to_num((cube - dark_ref) / (white_ref/0.40 - dark_ref)),
        0, 1.00).astype(np.float32)

# %%
all_preds = glob.glob('/home/nathaniel/Downloads/yogurt_data_deploy/*/*/*prediction_02_18_swir.npy')
thresh = [0.01,0.02,0.025, 0.05, 0.1, 0.2, 0.5]
for pred in tqdm(all_preds):
    # Load image file
    pred_img = np.load(pred)
    # Load the original cube
    cube_path = f"{pred.split('_prediction')[0]}.npy"
    print(cube_path)
    cube = np.load(cube_path)[::10,::10,:]
    cube = reflectance(cube, dark_ref, white_ref)
    # Generate the inference plot
    image_name = pred.split('/')[-1][:-4]
    save_path = f"/home/nathaniel/cubert/internal_rnd_applications/yogurt/results/{image_name}.png"
    fig, ax = create_inference_png(cube, pred_img, image_name, 1.0, plot_thresholds=thresh)
    fig.savefig(save_path)
    plt.close(fig)
    plt.ioff()
    gc.collect()
# Out:
#   0%|          | 0/1709 [00:00<?, ?it/s]
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime/20250121_121032_frame_31_ok_ok_rd4_rw9.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime/20250121_122146_frame_42_ok_nok_rd4_rw9.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime/20250121_121631_frame_37_ok_nok_rd4_rw9.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime/20250121_115901_frame_22_ok_ok_rd4_rw9.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime/20250121_123003_frame_53_nok_ok_rd4_rw9.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime/20250121_122715_frame_48_ok_ok_rd4_rw9.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime/20250121_120727_frame_29_ok_ok_rd4_rw9.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime/20250121_123223_frame_55_nok_ok_rd4_rw9.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime/20250121_122413_frame_45_ok_nok_rd4_rw9.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime/20250121_123349_frame_56_nok_ok_rd4_rw9.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime/20250121_123502_frame_57_nok_ok_rd4_rw9.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime/20250121_121908_frame_40_ok_nok_rd4_rw9.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime/20250121_122757_frame_50_ok_ok_rd4_rw9.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime/20250121_115411_frame_18_ok_ok_rd4_rw9.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime/20250121_122234_frame_44_ok_nok_rd4_rw9.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime/20250121_120920_frame_30_ok_ok_rd4_rw9.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime/20250121_123756_frame_60_nok_ok_rd4_rw9.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime/20250121_121325_frame_33_nok_ok_rd4_rw9.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime/20250121_121552_frame_36_ok_ok_rd4_rw9.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime/20250121_115934_frame_23_ok_ok_rd4_rw9.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime/20250121_121152_frame_32_nok_ok_rd4_rw9.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime/20250121_120603_frame_28_nok_ok_rd4_rw9.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime/20250121_122915_frame_52_ok_ok_rd4_rw9.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime/20250121_123906_frame_61_nok_ok_rd4_rw9.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime/20250121_122006_frame_41_ok_nok_rd4_rw9.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime/20250121_122510_frame_46_ok_nok_rd4_rw9.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime/20250121_121713_frame_38_ok_nok_rd4_rw9.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime/20250121_123101_frame_54_nok_ok_rd4_rw9.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime/20250121_121459_frame_35_nok_ok_rd4_rw9.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime/20250121_121845_frame_39_ok_nok_rd4_rw9.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime/20250121_121358_frame_34_ok_ok_rd4_rw9.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime/20250121_123713_frame_58_nok_ok_rd4_rw9.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime/20250121_115536_frame_21_ok_ok_rd4_rw9.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime/20250121_122834_frame_51_ok_ok_rd4_rw9.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime/20250121_115316_frame_17_ok_ok_rd4_rw9.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime/20250121_120442_frame_27_ok_ok_rd4_rw9.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime_mid/20250124_071937_frame_365_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime_mid/20250124_071721_frame_364_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime_mid/20250124_071034_frame_360_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime_mid/20250124_071411_frame_362_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime_after/20250124_103940_frame_715_ok_ok_rd9_rw38.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime_after/20250124_105031_frame_722_nok_nok_rd9_rw38.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime_after/20250124_105438_frame_726_ok_ok_rd9_rw38.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime_after/20250124_104844_frame_721_nok_ok_rd9_rw38.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime_after/20250124_110319_frame_734_ok_ok_rd9_rw38.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime_after/20250124_103856_frame_714_ok_ok_rd9_rw38.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime_after/20250124_110353_frame_735_nok_ok_rd9_rw38.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime_after/20250124_104530_frame_719_nok_ok_rd9_rw38.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime_after/20250124_105647_frame_728_nok_ok_rd9_rw38.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime_after/20250124_110235_frame_733_ok_ok_rd9_rw38.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime_after/20250124_105810_frame_729_nok_ok_rd9_rw38.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime_after/20250124_105938_frame_730_ok_nok_rd9_rw38.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime_after/20250124_105324_frame_723_nok_ok_rd9_rw38.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime_after/20250124_104404_frame_717_ok_ok_rd9_rw38.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime_after/20250124_104734_frame_720_nok_ok_rd9_rw38.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime_after/20250124_110117_frame_731_ok_nok_rd9_rw38.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime_after/20250124_105414_frame_725_nok_ok_rd9_rw38.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime_after/20250124_105530_frame_727_ok_ok_rd9_rw38.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime_after/20250124_110437_frame_736_nok_ok_rd9_rw38.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/friday_playtime_after/20250124_104101_frame_716_ok_ok_rd9_rw38.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/wednesday_playtime/20250122_105659_frame_1054_ok_nok_rd9_rw28.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/wednesday_playtime/20250122_110522_frame_1064_nok_ok_rd9_rw28.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/wednesday_playtime/20250122_111929_frame_1069_ok_ok_rd9_rw28.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/wednesday_playtime/20250122_113658_frame_1085_nok_ok_rd9_rw28.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/wednesday_playtime/20250122_105556_frame_1051_ok_nok_rd9_rw28.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/wednesday_playtime/20250122_105333_frame_1046_ok_nok_rd9_rw28.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/wednesday_playtime/20250122_105910_frame_1058_ok_nok_rd9_rw28.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/wednesday_playtime/20250122_105535_frame_1050_ok_nok_rd9_rw28.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/wednesday_playtime/20250122_112037_frame_1070_ok_ok_rd9_rw28.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/wednesday_playtime/20250122_113011_frame_1078_nok_ok_rd9_rw28.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/wednesday_playtime/20250122_105635_frame_1053_ok_nok_rd9_rw28.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/wednesday_playtime/20250122_112200_frame_1072_ok_ok_rd9_rw28.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/wednesday_playtime/20250122_105410_frame_1047_ok_nok_rd9_rw28.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/wednesday_playtime/20250122_111713_frame_1067_nok_ok_rd9_rw28.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/wednesday_playtime/20250122_110041_frame_1060_ok_nok_rd9_rw28.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/wednesday_playtime/20250122_113305_frame_1079_nok_ok_rd9_rw28.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/wednesday_playtime/20250122_105112_frame_1042_ok_ok_rd9_rw28.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/wednesday_playtime/20250122_105819_frame_1056_ok_nok_rd9_rw28.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/wednesday_playtime/20250122_110328_frame_1063_ok_ok_rd9_rw28.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/wednesday_playtime/20250122_113515_frame_1082_nok_nok_rd9_rw28.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/wednesday_playtime/20250122_105305_frame_1045_ok_nok_rd9_rw28.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/wednesday_playtime/20250122_112333_frame_1074_ok_ok_rd9_rw28.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/wednesday_playtime/20250122_110732_frame_1065_nok_ok_rd9_rw28.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/wednesday_playtime/20250122_110138_frame_1061_ok_nok_rd9_rw28.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/wednesday_playtime/20250122_111808_frame_1068_ok_ok_rd9_rw28.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/wednesday_playtime/20250122_113852_frame_1086_nok_ok_rd9_rw28.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/wednesday_playtime/20250122_110958_frame_1066_nok_ok_rd9_rw28.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/wednesday_playtime/20250122_105724_frame_1055_ok_nok_rd9_rw28.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/wednesday_playtime/20250122_112406_frame_1075_nok_ok_rd9_rw28.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/wednesday_playtime/20250122_112114_frame_1071_ok_ok_rd9_rw28.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/wednesday_playtime/20250122_113408_frame_1081_nok_nok_rd9_rw28.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/wednesday_playtime/20250122_105019_frame_1041_ok_ok_rd9_rw28.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/wednesday_playtime/20250122_110003_frame_1059_ok_nok_rd9_rw28.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/wednesday_playtime/20250122_112516_frame_1076_nok_ok_rd9_rw28.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/wednesday_playtime/20250122_110257_frame_1062_ok_nok_rd9_rw28.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/wednesday_playtime/20250122_112747_frame_1077_nok_ok_rd9_rw28.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/wednesday_playtime/20250122_112249_frame_1073_ok_ok_rd9_rw28.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/thursday_playtime/20250123_104455_frame_1050_ok_ok_rd19_rw26.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/thursday_playtime/20250123_102834_frame_1036_nok_ok_rd19_rw26.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/thursday_playtime/20250123_110525_frame_1075_nok_ok_rd19_rw26.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/thursday_playtime/20250123_110458_frame_1074_nok_ok_rd19_rw26.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/thursday_playtime/20250123_103154_frame_1038_ok_ok_rd19_rw26.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/thursday_playtime/20250123_103255_frame_1039_ok_nok_rd19_rw26.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/thursday_playtime/20250123_103321_frame_1040_ok_nok_rd19_rw26.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/thursday_playtime/20250123_105829_frame_1066_nok_ok_rd19_rw26.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/thursday_playtime/20250123_105624_frame_1063_nok_ok_rd19_rw26.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/thursday_playtime/20250123_104526_frame_1052_ok_ok_rd19_rw26.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/thursday_playtime/20250123_103905_frame_1046_ok_ok_rd19_rw26.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/thursday_playtime/20250123_103430_frame_1041_ok_ok_rd19_rw26.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/thursday_playtime/20250123_105932_frame_1067_nok_ok_rd19_rw26.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/thursday_playtime/20250123_105804_frame_1065_nok_ok_rd19_rw26.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/thursday_playtime/20250123_110422_frame_1072_nok_ok_rd19_rw26.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/thursday_playtime/20250123_103555_frame_1043_ok_nok_rd19_rw26.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/thursday_playtime/20250123_102420_frame_1035_nok_ok_rd19_rw26.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/thursday_playtime/20250123_105742_frame_1064_nok_ok_rd19_rw26.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/thursday_playtime/20250123_103945_frame_1047_ok_ok_rd19_rw26.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/thursday_playtime/20250123_110834_frame_1077_nok_ok_rd19_rw26.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/thursday_playtime/20250123_110649_frame_1076_nok_ok_rd19_rw26.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/thursday_playtime/20250123_104420_frame_1049_ok_ok_rd19_rw26.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/thursday_playtime/20250123_110253_frame_1070_ok_ok_rd19_rw26.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/thursday_playtime/20250123_103453_frame_1042_ok_nok_rd19_rw26.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/thursday_playtime/20250123_104916_frame_1055_nok_ok_rd19_rw26.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/thursday_playtime/20250123_104541_frame_1053_ok_ok_rd19_rw26.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/thursday_playtime/20250123_104630_frame_1054_nok_ok_rd19_rw26.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/thursday_playtime/20250123_105954_frame_1068_nok_ok_rd19_rw26.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/thursday_playtime/20250123_103805_frame_1045_ok_ok_rd19_rw26.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/thursday_playtime/20250123_105448_frame_1059_nok_ok_rd19_rw26.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/thursday_playtime/20250123_104334_frame_1048_nok_ok_rd19_rw26.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/thursday_playtime/20250123_102240_frame_1034_ok_ok_rd19_rw26.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/thursday_playtime/20250123_102931_frame_1037_nok_ok_rd19_rw26.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/thursday_playtime/20250123_105156_frame_1058_nok_ok_rd19_rw26.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/thursday_playtime/20250123_110109_frame_1069_nok_ok_rd19_rw26.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/thursday_playtime/20250123_103648_frame_1044_ok_nok_rd19_rw26.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/thursday_playtime/20250123_111002_frame_1079_nok_ok_rd19_rw26.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/thursday_playtime/20250123_102216_frame_1033_ok_ok_rd19_rw26.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/thursday_playtime/20250123_110319_frame_1071_nok_ok_rd19_rw26.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/thursday_playtime/20250123_105117_frame_1056_nok_ok_rd19_rw26.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/playtime/thursday_playtime/20250123_111044_frame_1081_nok_ok_rd19_rw26.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_054617_frame_136_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_101441_frame_888_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_055451_frame_174_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_055234_frame_163_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_063222_frame_355_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_053737_frame_98_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_073055_frame_575_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_103504_frame_1010_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_061150_frame_258_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_074330_frame_649_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_053834_frame_103_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_103718_frame_1023_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_073740_frame_614_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_102940_frame_978_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_103020_frame_982_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_055826_frame_189_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_071332_frame_515_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_094121_frame_728_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_053846_frame_104_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_100315_frame_827_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_102421_frame_947_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_061242_frame_264_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_100444_frame_835_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_054043_frame_109_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_074715_frame_675_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_062905_frame_339_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_073512_frame_599_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_074226_frame_642_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_074642_frame_670_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_062657_frame_329_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_074634_frame_669_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_053121_frame_69_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_102012_frame_919_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_103618_frame_1017_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_102526_frame_954_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_103649_frame_1020_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_093939_frame_721_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_095000_frame_774_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_103628_frame_1018_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_073837_frame_621_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_060738_frame_236_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_070231_frame_470_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_055415_frame_172_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_070142_frame_464_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_071317_frame_514_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_102801_frame_968_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_095757_frame_802_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_103229_frame_995_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_062956_frame_344_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_101715_frame_900_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_064557_frame_365_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_061014_frame_248_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_060806_frame_239_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_065957_frame_452_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_071805_frame_533_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_100619_frame_842_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_094459_frame_750_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_061353_frame_271_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_065022_frame_386_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_055112_frame_155_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_055807_frame_187_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_060823_frame_241_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_101138_frame_871_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_100845_frame_855_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_094434_frame_747_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_061548_frame_280_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_062546_frame_323_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_070117_frame_461_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_102203_frame_931_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_070125_frame_462_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_073021_frame_572_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_102908_frame_975_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_100521_frame_839_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_103728_frame_1024_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_071906_frame_540_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_073532_frame_601_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_094610_frame_756_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_093921_frame_719_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_101302_frame_879_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_074453_frame_660_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_095838_frame_805_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_060522_frame_227_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_074739_frame_679_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_094858_frame_773_nok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_065903_frame_444_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_102213_frame_932_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_101057_frame_866_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_062729_frame_333_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_073543_frame_603_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_070708_frame_497_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_102858_frame_974_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_055919_frame_192_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_095345_frame_785_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_094037_frame_724_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_070249_frame_472_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_054445_frame_128_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_101936_frame_915_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_065933_frame_449_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_052352_frame_37_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_065454_frame_417_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_065254_frame_403_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_075305_frame_703_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_102049_frame_924_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_102619_frame_958_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_102811_frame_969_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_054628_frame_137_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_053803_frame_100_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_054744_frame_140_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_054754_frame_141_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_063107_frame_349_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_065735_frame_434_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_071652_frame_531_nok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_095021_frame_776_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_100941_frame_860_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_060151_frame_206_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_072102_frame_549_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_103319_frame_1000_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_102042_frame_923_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_064436_frame_363_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_102136_frame_930_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_070158_frame_466_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_094046_frame_725_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_055942_frame_194_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_071242_frame_510_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_053858_frame_105_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_103357_frame_1003_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_094243_frame_737_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_061628_frame_284_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_100031_frame_813_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_071308_frame_513_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_062115_frame_302_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_072816_frame_568_nok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_100650_frame_845_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_055030_frame_151_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_060231_frame_210_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_064610_frame_366_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_100903_frame_857_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_054734_frame_139_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_054857_frame_147_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_074002_frame_627_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_062104_frame_301_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_102752_frame_967_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_103708_frame_1022_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_102732_frame_965_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_054526_frame_132_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_073747_frame_615_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_072134_frame_553_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_095357_frame_786_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_065221_frame_399_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_074407_frame_653_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_071823_frame_535_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_070547_frame_488_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_102431_frame_948_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_100530_frame_840_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_061336_frame_269_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_073607_frame_606_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_094825_frame_771_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_102646_frame_961_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_065602_frame_423_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_074026_frame_629_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_060354_frame_220_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_101903_frame_912_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_062259_frame_310_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_055906_frame_191_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_064424_frame_362_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_055626_frame_180_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_101213_frame_874_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_061719_frame_288_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_100248_frame_824_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_052332_frame_35_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_101014_frame_863_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_101403_frame_884_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_103157_frame_992_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_073654_frame_608_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_055142_frame_158_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_074315_frame_647_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_052514_frame_46_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_070701_frame_496_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_075315_frame_704_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_053411_frame_81_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_055154_frame_159_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_052722_frame_53_nok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_065646_frame_428_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_102656_frame_962_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_074725_frame_676_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_071233_frame_508_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_073126_frame_578_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_060337_frame_218_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_101346_frame_882_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_070652_frame_495_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_054547_frame_133_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_102839_frame_972_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_094130_frame_729_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_065830_frame_440_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_065502_frame_418_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_065942_frame_450_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_093847_frame_715_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_070440_frame_480_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_073449_frame_596_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_053545_frame_89_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_100539_frame_841_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_103639_frame_1019_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_071124_frame_502_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_094533_frame_754_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_102950_frame_979_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_073244_frame_584_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_094204_frame_733_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_073211_frame_581_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_100453_frame_836_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_074838_frame_685_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_070133_frame_463_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_053555_frame_90_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_053712_frame_96_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_071259_frame_512_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_102057_frame_925_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_075003_frame_689_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_062639_frame_327_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_071214_frame_506_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_052501_frame_44_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_073141_frame_579_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_070734_frame_500_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_102113_frame_927_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_071814_frame_534_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_055122_frame_156_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_100659_frame_846_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_095706_frame_798_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_072046_frame_547_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_100149_frame_818_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_064720_frame_373_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_055617_frame_179_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_061256_frame_266_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_055425_frame_173_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_060747_frame_237_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_061738_frame_290_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_074359_frame_652_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_100738_frame_849_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_103446_frame_1008_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_070452_frame_481_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_063214_frame_354_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_073335_frame_588_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_094629_frame_758_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_074201_frame_639_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_061216_frame_261_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_103548_frame_1014_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_072144_frame_554_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_065320_frame_407_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_102848_frame_973_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_053324_frame_77_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_095529_frame_792_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_100210_frame_820_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_103659_frame_1021_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_073828_frame_620_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_094253_frame_738_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_095152_frame_781_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_063052_frame_347_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_100407_frame_831_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_052548_frame_47_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_052431_frame_41_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_070533_frame_486_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_101114_frame_868_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_072402_frame_562_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_100931_frame_859_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_062038_frame_299_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_055541_frame_176_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_071939_frame_542_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_054911_frame_148_nok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_095127_frame_779_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_053132_frame_70_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_071950_frame_543_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_072939_frame_569_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_061121_frame_255_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_100239_frame_823_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_065839_frame_441_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_061004_frame_247_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_063022_frame_346_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_071440_frame_524_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_074755_frame_681_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_055639_frame_181_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_054815_frame_143_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_075253_frame_702_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_101945_frame_916_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_101920_frame_914_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_060127_frame_204_ok_ok_rd4_rw16.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/wednesday/20250122_055318_frame_167_ok_ok_rd4_rw16.npy
# ...
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_084140_frame_598_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_054034_frame_73_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_080716_frame_504_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_083355_frame_565_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_062142_frame_225_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_060104_frame_149_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_075853_frame_473_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_080049_frame_483_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_065915_frame_347_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_085222_frame_638_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_084534_frame_612_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_074854_frame_427_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_060451_frame_163_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_063628_frame_271_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_065332_frame_333_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_052733_frame_34_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_055336_frame_117_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_083639_frame_578_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_064016_frame_285_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_085821_frame_663_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_083621_frame_577_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_061507_frame_201_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_090221_frame_675_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_085703_frame_657_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_061317_frame_193_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_064106_frame_288_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_090358_frame_681_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_060336_frame_158_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_070358_frame_359_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_063014_frame_251_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_065537_frame_338_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_075621_frame_458_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_075658_frame_462_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_055648_frame_131_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_053155_frame_46_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_060650_frame_169_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_074827_frame_426_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_065630_frame_340_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_085753_frame_662_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_083410_frame_567_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_090016_frame_668_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_084040_frame_593_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_062337_frame_230_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_083538_frame_574_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_075009_frame_431_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_074053_frame_393_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_074617_frame_419_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_055630_frame_130_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_054806_frame_94_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_073940_frame_388_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_061539_frame_203_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_054856_frame_96_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_084054_frame_594_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_083805_frame_582_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_082957_frame_549_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_074631_frame_420_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_065254_frame_330_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_085535_frame_651_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_055050_frame_105_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_084655_frame_617_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_083215_frame_558_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_083517_frame_572_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_065054_frame_323_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_090310_frame_678_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_075940_frame_477_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_064341_frame_299_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_064724_frame_314_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_053903_frame_68_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_083050_frame_552_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_061132_frame_185_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_055101_frame_106_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_061020_frame_180_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_055948_frame_143_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_065953_frame_349_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_055740_frame_135_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_090123_frame_672_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_082442_frame_530_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_052829_frame_35_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_061441_frame_199_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_074934_frame_428_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_063445_frame_264_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_080730_frame_505_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_060220_frame_153_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_080038_frame_482_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_061408_frame_196_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_054424_frame_84_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_083345_frame_564_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_082736_frame_539_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_065020_frame_321_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_085546_frame_652_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_074015_frame_390_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_054834_frame_95_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_075753_frame_468_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_085509_frame_650_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_055933_frame_142_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_053116_frame_44_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_064855_frame_318_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_083100_frame_553_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_064451_frame_304_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_075233_frame_439_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_060429_frame_162_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_062041_frame_221_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_053443_frame_54_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_062737_frame_245_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_052717_frame_33_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_061631_frame_206_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_074120_frame_396_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_055131_frame_108_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_083010_frame_550_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_090540_frame_687_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_090035_frame_669_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_055601_frame_129_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_070145_frame_353_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_055828_frame_138_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_060233_frame_154_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_061743_frame_210_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_090000_frame_667_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_073551_frame_369_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_054019_frame_72_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_064831_frame_317_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_074212_frame_401_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_084604_frame_614_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_054406_frame_83_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_063456_frame_265_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_061525_frame_202_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_080834_frame_510_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_074801_frame_425_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_073827_frame_382_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_085126_frame_634_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_080846_frame_511_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_061453_frame_200_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_084412_frame_607_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_084105_frame_595_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_075250_frame_441_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_060910_frame_176_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_060846_frame_174_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_075241_frame_440_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_084516_frame_611_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_055803_frame_137_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_073535_frame_368_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_062558_frame_238_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_065113_frame_324_nok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_074240_frame_404_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_083831_frame_584_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_074645_frame_421_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_075802_frame_469_ok_ok_rd4_rw21.npy
# /home/nathaniel/Downloads/yogurt_data_deploy/train_eval/friday/20250124_073729_frame_376_ok_ok_rd4_rw21.npy
